# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame( {
    "days":[1,2,3,4,5,6],
    "temp":[34.6,45.7,23.6,56.8,34.6,23.0]
})
df
sns.lineplot(x = "days" ,y= "temp", data = df)

# %%
df = sns.load_dataset("iris.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#
# ...

# %%
df = sns.load_dataset("flights")
df.head()
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tips_df = sns.load_dataset("tips")
tips_df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.lineplot(x = "total_bill", y = "tip" , data = tips_df)
sns.lineplot(tips_df.total_bill , tips_df.tip)

# %%
sns.lineplot(x = 'size', y = 'total_bill',hue = 'time', data = tips_df)

# %%
sns.lineplot(x = 'size', y = 'total_bill',hue = 'smoker', data = tips_df , palette = "hot")

# %%
import matplotlib.pyplot as plt 

sns.lineplot(x = "size", y = "total_bill", hue = "sex",palette = "hot", data = tips_df,
             dashes = True, markers = ["o", "*"])

plt.title("Line Plot", fontsize = 65)    # for title
plt.xlabel("size", fontsize = 15)        # label for x-axis
plt.ylabel("Total Bill", fontsize = 35)  # label for y-axis
#plt.legend()
plt.show()

# %%
sns.lineplot(x = "tip", y = "total_bill", data

# %%
tips_df = sns.load_dataset("tips")
tips_df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.distplot(tips_df["total_bill"],bins = 100)

# %%
sns.barplot(x = 'day', y = 'total_bill',hue = 'sex', data = tips_df)

# %%
hue_order = ['Female','Male']
sns.barplot(x = 'day', y = 'total_bill',hue = 'sex', data = tips_df ,  hue_order = hue_order)

# %%
sns.barplot(x = 'day', y = 'total_bill',hue = 'sex', data = tips_df , estimator=np.mean)

# %%
sns.barplot(x = 'day', y = 'total_bill',hue = 'sex', data = tips_df , estimator=np.max)

# %%
sns.barplot(x = 'day', y = 'total_bill',hue = 'sex', data = tips_df , ci = 20)
